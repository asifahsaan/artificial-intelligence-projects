# %% [markdown]
# <a href="https://colab.research.google.com/github/azmat07-CS/artificial-intelligence-projects/blob/azmat-ullah/Copy_of_train_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries (only needed in Colab)
# !pip install tensorflow numpy matplotlib opencv-python --quiet

# Import libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
